# %%
import pandas as pd
import numpy as np

# Opsi 2
df = pd.read_csv('response.csv', encoding='iso-8859-1')
df
# Out:
#                Timestamp     Usia   Jenis Kelamin     Jenjang Pendidikan    \
# 0    04/07/2025 22:36:03       23         laki-laki                     S1
# 1    04/07/2025 22:36:33       24         laki-laki                     S1
# 2    04/07/2025 22:45:59       25         laki-laki                     S1
# 3    04/07/2025 22:51:39       21         laki-laki                     S1
# 4    04/07/2025 23:09:11       21         Perempuan                     S1
# ..                   ...      ...               ...                    ...
# 211  19/07/2025 03:34:16  23 - 25         laki-laki                     S3
# 212  19/07/2025 03:34:20  26 - 30         laki-laki                     S2
# 213  19/07/2025 03:34:35  26 - 30         laki-laki                     S2
# 214  19/07/2025 03:34:40  21 - 22         laki-laki                     D3
# 215  19/07/2025 03:34:50  21 - 22         laki-laki                     D3
#
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 19 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   Timestamp                                                                                        216 non-null    object
#  1   Usia                                                                                             216 non-null    object
#  2     Jenis Kelamin                                                                                  216 non-null    object
#  3     Jenjang Pendidikan                                                                             216 non-null    object
#  4   Apakah Anda berasal dari keluarga berpenghasilan di bawah Rp 3.500.000 per bulan?                216 non-null    object
# ...
